# %%
print("Jai Bajrang Bali")

# %%
import pandas as pd
from pymongo import MongoClient
from IPython.display import display

client = MongoClient("your mongo url")
db = client["Amazon"]
collection = db["products"]

# Fetch products
products = list(collection.find({}))

# Prepare flat list for DataFrame
flattened_products = []

for p in products:
    flat = {
        "productId": p.get("productId"),
        "name": p.get("name"),
        "description": p.get("description"),
        "isOrganic": p.get("isOrganic", False),
        "tags": ", ".join(p.get("tags", [])),
        "images": ", ".join(p.get("images", [])),
        "basePrice": p.get("basePrice"),
        "sustainableScore": p.get("sustainableScore", 0),
        "energyUsed": p.get("energyUsed", 0),
        "emissions": p.get("emissions", 0),
        "greenPoints": p.get("greenPoints", 0),
        "waterSaved": p.get("waterSaved", 0),
        "plasticAvoided": p.get("plasticAvoided", 0),
        "createdAt": p.get("createdAt")
    }
    flattened_products.append(flat)

 # here we are not adding like details and variety beacuse it is not usefull;


pd.set_option("display.max_columns", None)    
pd.set_option("display.width", 1000)            
pd.set_option("display.max_colwidth", None)  

# Create DataFrame
df = pd.DataFrame(flattened_products)
# df.to_csv("products_clean.csv", index=False)

# x=df.to_excel("products_clean_Excel.xlsx", index=False)

# %%
# Now train the model
import pandas as pd
from IPython.display import display
df = pd.read_csv("products_clean.csv")

print(display(df.head()))

# Combine important fields into a single string for embedding
df["text_for_embedding"] = (
    df["name"].fillna("") + " " +
    df["description"].fillna("") + " " +
    df["tags"].fillna("") + " " +
    df["isOrganic"].apply(lambda x: "organic product" if x else "non-organic product") + " " +
    df["sustainableScore"].apply(lambda x: "high sustainability score" if x > 75 else "low sustainability score")
)

print(df["text_for_embedding"])

# %%
from sentence_transformers import SentenceTransformer, util
model = SentenceTransformer("all-MiniLM-L6-v2")
product_embeddings = model.encode(df["text_for_embedding"].tolist(), convert_to_tensor=True)
def search_products(query, top_k=20):
    query_embedding = model.encode(query, convert_to_tensor=True)
    cosine_scores = util.cos_sim(query_embedding, product_embeddings)[0]

    # Attach scores to DataFrame
    df["similarity"] = cosine_scores.cpu().numpy()
    
    # Split based on eco filters
    eco = df[(df["isOrganic"] == True) & (df["sustainableScore"] >= 75)]
    rest = df[~df.index.isin(eco.index)]

    # Sort each group by similarity
    eco_sorted = eco.sort_values(by="similarity", ascending=False)
    rest_sorted = rest.sort_values(by="similarity", ascending=False)

    # Concatenate top-k results
    final_df = pd.concat([eco_sorted.head(10), rest_sorted.head(top_k - 10)])

    # Return simplified output
    return final_df[["name", "description", "tags", "isOrganic", "sustainableScore", "similarity"]]

results = search_products("cleaning agent", top_k=20)
print(results.to_string(index=False))
# Out:
#                                                                                    name                                                                                                                                                                                                                                                                                                                                                                                                      description                                                                                               tags  isOrganic  sustainableScore  similarity
#                          Herbal Strategi Bathroom Cleaner – 500 mL Spray (Herbal Lemon)                                                                                                                                                                                                                                  Completely herbal bathroom cleaner with fragrant lemon oil that removes hard-water stains and kills bacteria. Eco-friendly, biodegradable, and safe for skin, babies, and pets.                        bathroom cleaner, herbal cleaner, antibacterial spray, eco-friendly cleaner       True             85.00    0.445066
#                      Nimyle Herbal Eco-Friendly Floor Cleaner – Neem-Infused 2 L Liquid A powerful herbal floor cleaner infused with neem extracts that delivers 99.9% antibacterial protection. Formulated with plant-based surfactants and natural neem, this eco-friendly liquid cleans effectively, neutralizes odors, and leaves a fresh herbal scent. Mild on surfaces yet tough on germs—perfect for homes with children and pets. Biodegradable, non-toxic, and packaged in a recyclable bottle.                                                                    eco-friendly, home-essentials,        True             89.00    0.430885
#                                              Odo‑Rite Pet Area Freshener – 200 mL Spray                                                                                                                                                                                                                                                                           Biodegradable, bio‑technological pet odor remover spray that works in 30 seconds. Pet-safe, child-safe, and effective on all surfaces.                                    pet area freshener, odor remover, biodegradable spray, pet-safe       True             86.00    0.416431
#                         SOFTSPUN Microfiber Cleaning Cloths – 4pcs, 40 × 40 cm, 340 GSM                                                                                                                                                                                                                                                                             High‑absorbency lint and streak‑free microfiber cloths ideal for multipurpose cleaning. Durable, reusable, and safe on all surfaces.                                  microfiber cloth, cleaning cloth, streak-free, multipurpose cloth       True             81.00    0.411810
#                                                            PUER Organic Dishwashing Gel                                                                                                                                                                                                                                                                       Concentrated plant-based gel made with natural enzymes and essential oils. Tough on grease, gentle on hands, and completely biodegradable.                          dishwash, organic dish gel, biodegradable cleaner, eco-friendly detergent       True             90.00    0.392434
#                                Born Good Plant Based Toilet Cleaner – Arctic Air 500 mL                                                                                                                                                                                                                                                 Biodegradable, plant-based toilet cleaner with Arctic Air fragrance that's non-toxic and eco‑friendly. Safe for septic systems and effective on stains and odor.                              toilet cleaner, plant-based cleaner, biodegradable cleaner, non-toxic       True             87.00    0.379546
#                                                              Biodegradable Sanitary Pad                                                                                                                                                                                                                                                                Sirona Biodegradable Super Soft Black Sanitary Pads/Napkins, Antibacterial, Ultra Thin and Rash Free Protection - Small (S) Day Pads (Pack of 10)                                                                            hygiene, eco-friendly,        True             79.00    0.372231
#                                  SacredEarth Natural Dish Wash Liquid – 500 mL × 2 Pack                                                                                                                                                                                                                                             Plant-based dish wash liquid with soap nuts, lemon, lemongrass, thyme, and bergamot. Biodegradable, non-toxic, and gentle on hands while effectively cutting grease.                          dishwash, natural dish soap, biodegradable cleaner, plant-based detergent       True             89.00    0.365498
#                                                                   Happi Dishwash Liquid                                                                                                                                                                                                                                                                                                                                                                                          Organic Dishwash Liquid                                                                                dishwash, organic,        True             77.00    0.356332
#                                                                     EVEREVE cotton pads                                                                                                                                                                                                               Evereve Multipurpose Cotton Pads, 200 Pcs, 100% Cotton, With Aloe Vera Extracts, Embossed, Double Sided, For Skin Cleaning, Eye & Face Makeup Removal, Nail Polish Removal, Pack of 2 (100's each)                                                                           personal care, organic,        True             87.00    0.328986
#                                          Spontaneous Small Rolling Luggage Brush Blue C                                                                                                                                                                                                                                                                                                                                             Imported from Kaggle: Spontaneous Small Rolling Luggage Brush Blue C                                                                                       category_104      False              0.00    0.302736
#                                                                Random House UP-020 Book                                                                                                                                                                                                                       Random House's premium quality books product offering top-notch performance and durability. Highly rated and trusted by users globally. Great for daily use. Built with quality materials.                        books, study, reading, house, the random house, eco-friendly, biodegradable       True             66.77    0.294769
#            Men's Polo Scrub Top, Modern Sporty V-Neck with Breathable Mesh Fabric WW615                                                                                                                                                                                                                                                                                                                                     Men's Polo Scrub Top, Modern Sporty V-Neck with Breathable Mesh Fabric WW615                             mens, scrub, top, sporty, vneck, breathable, mesh, fabric, ww615, polo      False              0.00    0.292562
# Clean Up Crew Operator Skull Men's Graphic Short Sleeve T-Shirt - Athletic Fit Tees Men                                                                                                                                                                                                                                                                                                                          Clean Up Crew Operator Skull Men's Graphic Short Sleeve T-Shirt - Athletic Fit Tees Men                                         clean, operator, skull, mens, graphic, tshirt, tees, shirt      False              0.00    0.281378
#                                                                Random House Bj-560 Book                                                                                                                                                                                                                       Random House's premium quality books product offering top-notch performance and durability. Highly rated and trusted by users globally. Great for daily use. Built with quality materials.                        books, study, reading, house, the random house, eco-friendly, biodegradable       True             74.10    0.281091
#                                                  Gillette cL-323 Health & Personal Care                                                                                                                                                                                                          Gillette's premium quality health & personal care product offering top-notch performance and durability. Highly rated and trusted by users globally. Great for daily use. Built with quality materials. health & personal care, health, personal care, gillette, gel, shaving, eco-friendly, biodegradable       True             60.65    0.280211
#                                                  Men’s Robe, Kimono Waffle Spa Bathrobe                                                                                                                                                                                                                                                                                                                                                                           Men’s Robe, Kimono Waffle Spa Bathrobe                                                          mens, robe, kimono, waffle, spa, bathrobe      False              0.00    0.275987
#                                                                Random House mH-691 Book                                                                                                                                                                                                                       Random House's premium quality books product offering top-notch performance and durability. Highly rated and trusted by users globally. Great for daily use. Built with quality materials.                                          books, study, reading, house, the random house, etiquette      False              0.00    0.269506
#                                                           Philips dd-976 Home & Kitchen                                                                                                                                                                                                                   Philips's premium quality home & kitchen product offering top-notch performance and durability. Highly rated and trusted by users globally. Great for daily use. Built with quality materials.                    home & kitchen, kitchen, home, phillips, automatic cooking, food-maker, cooking      False              0.00    0.269195
#                                                                 Bosch PY-915 Automotive                                                                                                                                                                                                                         Bosch's premium quality automotive product offering top-notch performance and durability. Highly rated and trusted by users globally. Great for daily use. Built with quality materials.                                      automotive, home essentials, bosch, inverter battery, battery      False              0.00    0.268807

# %%
from sentence_transformers import SentenceTransformer, util
import pandas as pd

model = SentenceTransformer("all-MiniLM-L6-v2")

# Encode all product texts once
product_embeddings = model.encode(df["text_for_embedding"].tolist(), convert_to_tensor=True)

def search_products(query, top_k=20):
    # Step 1: Encode the user query
    query_embedding = model.encode(query, convert_to_tensor=True)
    cosine_scores = util.cos_sim(query_embedding, product_embeddings)[0]
    
    # Step 2: Attach similarity scores to DataFrame
    df["similarity"] = cosine_scores.cpu().numpy()
    
    # Step 3: Prioritize eco-friendly products
    eco = df[(df["isOrganic"] == True) & (df["sustainableScore"] >= 75)]
    rest = df[~df.index.isin(eco.index)]

    # Step 4: Sort by similarity
    eco_sorted = eco.sort_values(by="similarity", ascending=False)
    rest_sorted = rest.sort_values(by="similarity", ascending=False)

    # Step 5: Combine results
    final_df = pd.concat([eco_sorted.head(10), rest_sorted.head(top_k - 10)])

    # ✅ Return full product info sorted by similarity
    return final_df.sort_values(by="similarity", ascending=False)

# Example usage
def display_full_product_details(results_df):
    for idx, row in results_df.iterrows():
        print(f"\n{'='*100}")
        print(f"🔢 Product #{idx + 1}")
        print(f"🆔 Product ID       : {row.get('productId', 'N/A')}")
        print(f"🛒 Name             : {row.get('name', 'N/A')}")
        print(f"🖼️  Image URL       : {row.get('images', '').split(',')[0] if row.get('images') else 'No image'}")
        print(f"📄 Description      : {row.get('description', '')[:100]}{'...' if len(row.get('description', '')) > 100 else ''}")
        print(f"🏷️  Tags            : {row.get('tags', 'None')}")
        print(f"🌱 Organic          : {'✅ Yes' if row.get('isOrganic') else '❌ No'}")
        print(f"📦 Base Price       : ₹{row.get('basePrice', 'N/A')}")
        print(f"📊 Sustainable Score: {row.get('sustainableScore', 0)}/100")
        print(f"🟩 Green Points     : {row.get('greenPoints', 0)}")
        print(f"🌍 Emissions        : {row.get('emissions', 0)} kg CO₂")
        print(f"💧 Water Saved      : {row.get('waterSaved', 0)} L")
        print(f"🧪 Energy Used      : {row.get('energyUsed', 0)} kWh")
        print(f"🚯 Plastic Avoided  : {row.get('plasticAvoided', 0)} g")
        print(f"🕒 Created At       : {row.get('createdAt', 'N/A')}")
        print(f"📈 Similarity Score : {row.get('similarity', 0):.4f}")
        print(f"{'='*100}")

# Run and display
results = search_products("mens tshirt", top_k=20)
display_full_product_details(results)
# Out:
# ====================================================================================================
# 🔢 Product #40
# 🆔 Product ID       : herbal-strategi-bathroom-cleaner-500ml
# 🛒 Name             : Herbal Strategi Bathroom Cleaner – 500 mL Spray (Herbal Lemon)
# 🖼️  Image URL       : https://res.cloudinary.com/ddr2iwcho/image/upload/v1750101494/products/nbijs5mlm4yxle2zqdg9.jpg
# 📄 Description      : Completely herbal bathroom cleaner with fragrant lemon oil that removes hard-water stains and kills ...
# 🏷️  Tags            : bathroom cleaner, herbal cleaner, antibacterial spray, eco-friendly cleaner
# 🌱 Organic          : ✅ Yes
# 📦 Base Price       : ₹299.0
# 📊 Sustainable Score: 85.0/100
# 🟩 Green Points     : 78.0
# 🌍 Emissions        : 13.0 kg CO₂
# 💧 Water Saved      : 29.0 L
# 🧪 Energy Used      : 20.0 kWh
# 🚯 Plastic Avoided  : 25.0 g
# 🕒 Created At       : 2025-06-16 19:18:17.055
# 📈 Similarity Score : 0.4451
# ====================================================================================================
#
# ====================================================================================================
# 🔢 Product #37
# 🆔 Product ID       : 1f0dce59-c6a0-45fc-a3eb-a21ab5ae2128
# 🛒 Name             : Nimyle Herbal Eco-Friendly Floor Cleaner – Neem-Infused 2 L Liquid
# 🖼️  Image URL       : https://res.cloudinary.com/ddr2iwcho/image/upload/v1750100066/products/gvqjaz0sqdmq1eivycbp.jpg
# 📄 Description      : A powerful herbal floor cleaner infused with neem extracts that delivers 99.9% antibacterial protect...
# 🏷️  Tags            : eco-friendly, home-essentials,
# 🌱 Organic          : ✅ Yes
# 📦 Base Price       : ₹500.0
# 📊 Sustainable Score: 89.0/100
# 🟩 Green Points     : 59.0
# 🌍 Emissions        : 50.0 kg CO₂
# 💧 Water Saved      : 60.0 L
# 🧪 Energy Used      : 76.0 kWh
# 🚯 Plastic Avoided  : 6.0 g
# 🕒 Created At       : 2025-06-16 18:54:31.827
# 📈 Similarity Score : 0.4309
# ====================================================================================================
#
# ====================================================================================================
# 🔢 Product #46
# 🆔 Product ID       : dafef318-63ce-482a-afdf-fb09b4bf70a8
# 🛒 Name             : Odo‑Rite Pet Area Freshener – 200 mL Spray
# 🖼️  Image URL       : https://res.cloudinary.com/ddr2iwcho/image/upload/v1750102710/products/fx2qm9cprra8pcbfvgx4.jpg
# 📄 Description      : Biodegradable, bio‑technological pet odor remover spray that works in 30 seconds. Pet-safe, child-sa...
# 🏷️  Tags            : pet area freshener, odor remover, biodegradable spray, pet-safe
# 🌱 Organic          : ✅ Yes
# 📦 Base Price       : ₹299.0
# 📊 Sustainable Score: 86.0/100
# 🟩 Green Points     : 80.0
# 🌍 Emissions        : 14.0 kg CO₂
# 💧 Water Saved      : 30.0 L
# 🧪 Energy Used      : 22.0 kWh
# 🚯 Plastic Avoided  : 24.0 g
# 🕒 Created At       : 2025-06-16 19:38:33.384
# 📈 Similarity Score : 0.4164
# ====================================================================================================
#
# ====================================================================================================
# 🔢 Product #38
# 🆔 Product ID       : softspun-microfiber-4pcs
# 🛒 Name             : SOFTSPUN Microfiber Cleaning Cloths – 4pcs, 40 × 40 cm, 340 GSM
# 🖼️  Image URL       : https://res.cloudinary.com/ddr2iwcho/image/upload/v1750101121/products/gk131zwp8jqsulqmjejd.jpg
# 📄 Description      : High‑absorbency lint and streak‑free microfiber cloths ideal for multipurpose cleaning. Durable, reu...
# 🏷️  Tags            : microfiber cloth, cleaning cloth, streak-free, multipurpose cloth
# 🌱 Organic          : ✅ Yes
# 📦 Base Price       : ₹599.0
# 📊 Sustainable Score: 81.0/100
# 🟩 Green Points     : 73.0
# 🌍 Emissions        : 11.0 kg CO₂
# 💧 Water Saved      : 28.0 L
# 🧪 Energy Used      : 17.0 kWh
# 🚯 Plastic Avoided  : 20.0 g
# 🕒 Created At       : 2025-06-16 19:12:03.106
# 📈 Similarity Score : 0.4118
# ====================================================================================================
#
# ====================================================================================================
# 🔢 Product #158
# 🆔 Product ID       : 4fdbed07-157c-49c8-860d-bbe8151345f7
# 🛒 Name             : PUER Organic Dishwashing Gel
# 🖼️  Image URL       : https://res.cloudinary.com/ddr2iwcho/image/upload/v1750105897/products/lsvzgwk9xlfvud95a2m7.png
# 📄 Description      : Concentrated plant-based gel made with natural enzymes and essential oils. Tough on grease, gentle o...
# 🏷️  Tags            : dishwash, organic dish gel, biodegradable cleaner, eco-friendly detergent
# 🌱 Organic          : ✅ Yes
# 📦 Base Price       : ₹325.0
# 📊 Sustainable Score: 90.0/100
# 🟩 Green Points     : 85.0
# 🌍 Emissions        : 11.0 kg CO₂
# 💧 Water Saved      : 25.0 L
# 🧪 Energy Used      : 16.0 kWh
# 🚯 Plastic Avoided  : 20.0 g
# 🕒 Created At       : 2025-06-16 20:31:41.639
# 📈 Similarity Score : 0.3924
# ====================================================================================================
#
# ====================================================================================================
# 🔢 Product #41
# 🆔 Product ID       : born-good-toilet-cleaner-arctic-air-500ml
# 🛒 Name             : Born Good Plant Based Toilet Cleaner – Arctic Air 500 mL
# 🖼️  Image URL       : https://res.cloudinary.com/ddr2iwcho/image/upload/v1750101710/products/dshybvfg0kmwzz44hwve.jpg
# 📄 Description      : Biodegradable, plant-based toilet cleaner with Arctic Air fragrance that's non-toxic and eco‑friendl...
# 🏷️  Tags            : toilet cleaner, plant-based cleaner, biodegradable cleaner, non-toxic
# 🌱 Organic          : ✅ Yes
# 📦 Base Price       : ₹349.0
# 📊 Sustainable Score: 87.0/100
# 🟩 Green Points     : 80.0
# 🌍 Emissions        : 12.0 kg CO₂
# 💧 Water Saved      : 32.0 L
# 🧪 Energy Used      : 19.0 kWh
# 🚯 Plastic Avoided  : 24.0 g
# 🕒 Created At       : 2025-06-16 19:21:52.156
# 📈 Similarity Score : 0.3795
# ====================================================================================================
#
# ====================================================================================================
# 🔢 Product #31
# 🆔 Product ID       : 25bfb69c-2593-4309-bc62-cf4fb00d222a
# 🛒 Name             : Biodegradable Sanitary Pad
# 🖼️  Image URL       : https://res.cloudinary.com/ddr2iwcho/image/upload/v1750096875/products/o5phup7eybjsilahknjj.jpg
# 📄 Description      : Sirona Biodegradable Super Soft Black Sanitary Pads/Napkins, Antibacterial, Ultra Thin and Rash Free...
# 🏷️  Tags            : hygiene, eco-friendly,
# 🌱 Organic          : ✅ Yes
# 📦 Base Price       : ₹249.0
# 📊 Sustainable Score: 79.0/100
# 🟩 Green Points     : 50.0
# 🌍 Emissions        : 58.0 kg CO₂
# 💧 Water Saved      : 48.0 L
# 🧪 Energy Used      : 86.0 kWh
# 🚯 Plastic Avoided  : 6.0 g
# 🕒 Created At       : 2025-06-16 18:01:18.494
# 📈 Similarity Score : 0.3722
# ====================================================================================================
#
# ====================================================================================================
# 🔢 Product #157
# 🆔 Product ID       : ab5b35ed-263b-42df-be5b-2cbcc8fc6715
# 🛒 Name             : SacredEarth Natural Dish Wash Liquid – 500 mL × 2 Pack
# 🖼️  Image URL       : https://res.cloudinary.com/ddr2iwcho/image/upload/v1750105582/products/hr1hmxfmxju3ghbuh5ra.jpg
# 📄 Description      : Plant-based dish wash liquid with soap nuts, lemon, lemongrass, thyme, and bergamot. Biodegradable, ...
# 🏷️  Tags            : dishwash, natural dish soap, biodegradable cleaner, plant-based detergent
# 🌱 Organic          : ✅ Yes
# 📦 Base Price       : ₹549.0
# 📊 Sustainable Score: 89.0/100
# 🟩 Green Points     : 83.0
# 🌍 Emissions        : 13.0 kg CO₂
# 💧 Water Saved      : 29.0 L
# 🧪 Energy Used      : 19.0 kWh
# 🚯 Plastic Avoided  : 26.0 g
# 🕒 Created At       : 2025-06-16 20:26:23.837
# 📈 Similarity Score : 0.3655
# ====================================================================================================
#
# ====================================================================================================
# 🔢 Product #2
# 🆔 Product ID       : c5c85bcb-2be2-4d56-8b4b-3685543ef98e
# 🛒 Name             : Happi Dishwash Liquid
# 🖼️  Image URL       : https://res.cloudinary.com/ddr2iwcho/image/upload/v1750078770/products/fx0jj1zzksoanospurr1.jpg
# 📄 Description      : Organic Dishwash Liquid
# 🏷️  Tags            : dishwash, organic,
# 🌱 Organic          : ✅ Yes
# 📦 Base Price       : ₹249.0
# 📊 Sustainable Score: 77.0/100
# 🟩 Green Points     : 97.0
# 🌍 Emissions        : 35.0 kg CO₂
# 💧 Water Saved      : 70.0 L
# 🧪 Energy Used      : 90.0 kWh
# 🚯 Plastic Avoided  : 3.0 g
# 🕒 Created At       : 2025-06-16 12:59:32.950
# 📈 Similarity Score : 0.3563
# ====================================================================================================
#
# ====================================================================================================
# 🔢 Product #21
# 🆔 Product ID       : 3fad0211-4db6-4d88-9120-0f710baa2926
# 🛒 Name             : EVEREVE cotton pads
# 🖼️  Image URL       : https://res.cloudinary.com/ddr2iwcho/image/upload/v1750085151/products/qby2kdhammxbxmxbpgkn.jpg
# 📄 Description      : Evereve Multipurpose Cotton Pads, 200 Pcs, 100% Cotton, With Aloe Vera Extracts, Embossed, Double Si...
# 🏷️  Tags            : personal care, organic,
# 🌱 Organic          : ✅ Yes
# 📦 Base Price       : ₹179.98
# 📊 Sustainable Score: 87.0/100
# 🟩 Green Points     : 60.0
# 🌍 Emissions        : 56.0 kg CO₂
# 💧 Water Saved      : 59.0 L
# 🧪 Energy Used      : 47.0 kWh
# 🚯 Plastic Avoided  : 4.0 g
# 🕒 Created At       : 2025-06-16 14:45:53.418
# 📈 Similarity Score : 0.3290
# ====================================================================================================
#
# ====================================================================================================
# 🔢 Product #611
# 🆔 Product ID       : 4b1548fe-6bd6-43b2-85b3-bf7f38d75902
# 🛒 Name             : Spontaneous Small Rolling Luggage Brush Blue C
# 🖼️  Image URL       : https://m.media-amazon.com/images/I/619X+hlDWVL._AC_UL320_.jpg
# 📄 Description      : Imported from Kaggle: Spontaneous Small Rolling Luggage Brush Blue C
# 🏷️  Tags            : category_104
# 🌱 Organic          : ❌ No
# 📦 Base Price       : ₹229.0
# 📊 Sustainable Score: 0.0/100
# 🟩 Green Points     : 0.0
# 🌍 Emissions        : 0.0 kg CO₂
# 💧 Water Saved      : 0.0 L
# 🧪 Energy Used      : 0.0 kWh
# 🚯 Plastic Avoided  : 0.0 g
# 🕒 Created At       : 2025-06-17 10:43:41.517
# 📈 Similarity Score : 0.3027
# ====================================================================================================
#
# ====================================================================================================
# 🔢 Product #98
# 🆔 Product ID       : P000128
# 🛒 Name             : Random House UP-020 Book
# 🖼️  Image URL       : https://res.cloudinary.com/ddr2iwcho/image/upload/v1750104224/products/fia5svusegrka45lwh5k.jpg
# 📄 Description      : Random House's premium quality books product offering top-notch performance and durability. Highly r...
# 🏷️  Tags            : books, study, reading, house, the random house, eco-friendly, biodegradable
# 🌱 Organic          : ✅ Yes
# 📦 Base Price       : ₹606.0
# 📊 Sustainable Score: 66.77/100
# 🟩 Green Points     : 80.38
# 🌍 Emissions        : 14.64 kg CO₂
# 💧 Water Saved      : 34.95 L
# 🧪 Energy Used      : 86.12 kWh
# 🚯 Plastic Avoided  : 45.93 g
# 🕒 Created At       : 2025-06-16 20:03:46.284
# 📈 Similarity Score : 0.2948
# ====================================================================================================
#
# ====================================================================================================
# 🔢 Product #3308
# 🆔 Product ID       : 36a2e66d-0fff-4976-9e07-3ee59dd5f0b9
# 🛒 Name             : Men's Polo Scrub Top, Modern Sporty V-Neck with Breathable Mesh Fabric WW615
# 🖼️  Image URL       : https://m.media-amazon.com/images/I/61esh-ojzRL._AC_UL320_.jpg
# 📄 Description      : Men's Polo Scrub Top, Modern Sporty V-Neck with Breathable Mesh Fabric WW615
# 🏷️  Tags            : mens, scrub, top, sporty, vneck, breathable, mesh, fabric, ww615, polo
# 🌱 Organic          : ❌ No
# 📦 Base Price       : ₹32.0
# 📊 Sustainable Score: 0.0/100
# 🟩 Green Points     : 0.0
# 🌍 Emissions        : 0.0 kg CO₂
# 💧 Water Saved      : 0.0 L
# 🧪 Energy Used      : 0.0 kWh
# 🚯 Plastic Avoided  : 0.0 g
# 🕒 Created At       : 2025-06-18 02:15:09.411
# 📈 Similarity Score : 0.2926
# ====================================================================================================
#
# ====================================================================================================
# 🔢 Product #3829
# 🆔 Product ID       : fb410df6-be0c-47c0-ad66-58f88f52e4f1
# 🛒 Name             : Clean Up Crew Operator Skull Men's Graphic Short Sleeve T-Shirt - Athletic Fit Tees Men
# 🖼️  Image URL       : https://m.media-amazon.com/images/I/71Fbvp4H-jL._AC_UL320_.jpg
# 📄 Description      : Clean Up Crew Operator Skull Men's Graphic Short Sleeve T-Shirt - Athletic Fit Tees Men
# 🏷️  Tags            : clean, operator, skull, mens, graphic, tshirt, tees, shirt
# 🌱 Organic          : ❌ No
# 📦 Base Price       : ₹30.0
# 📊 Sustainable Score: 0.0/100
# 🟩 Green Points     : 0.0
# 🌍 Emissions        : 0.0 kg CO₂
# 💧 Water Saved      : 0.0 L
# 🧪 Energy Used      : 0.0 kWh
# 🚯 Plastic Avoided  : 0.0 g
# 🕒 Created At       : 2025-06-18 02:16:54.265
# 📈 Similarity Score : 0.2814
# ====================================================================================================
#
# ====================================================================================================
# 🔢 Product #96
# 🆔 Product ID       : P000125
# 🛒 Name             : Random House Bj-560 Book
# 🖼️  Image URL       : https://res.cloudinary.com/ddr2iwcho/image/upload/v1750104219/products/oufqewwokijj8ujx8i1j.jpg
# 📄 Description      : Random House's premium quality books product offering top-notch performance and durability. Highly r...
# 🏷️  Tags            : books, study, reading, house, the random house, eco-friendly, biodegradable
# 🌱 Organic          : ✅ Yes
# 📦 Base Price       : ₹1341.0
# 📊 Sustainable Score: 74.1/100
# 🟩 Green Points     : 68.02
# 🌍 Emissions        : 7.8 kg CO₂
# 💧 Water Saved      : 17.67 L
# 🧪 Energy Used      : 50.66 kWh
# 🚯 Plastic Avoided  : 65.61 g
# 🕒 Created At       : 2025-06-16 20:03:41.690
# 📈 Similarity Score : 0.2811
# ====================================================================================================
#
# ====================================================================================================
# 🔢 Product #114
# 🆔 Product ID       : P000181
# 🛒 Name             : Gillette cL-323 Health & Personal Care
# 🖼️  Image URL       : https://res.cloudinary.com/ddr2iwcho/image/upload/v1750104262/products/kgvixsdotomtxieh0xtw.jpg
# 📄 Description      : Gillette's premium quality health & personal care product offering top-notch performance and durabil...
# 🏷️  Tags            : health & personal care, health, personal care, gillette, gel, shaving, eco-friendly, biodegradable
# 🌱 Organic          : ✅ Yes
# 📦 Base Price       : ₹860.0
# 📊 Sustainable Score: 60.65/100
# 🟩 Green Points     : 58.48
# 🌍 Emissions        : 13.91 kg CO₂
# 💧 Water Saved      : 26.76 L
# 🧪 Energy Used      : 38.47 kWh
# 🚯 Plastic Avoided  : 36.4 g
# 🕒 Created At       : 2025-06-16 20:04:23.740
# 📈 Similarity Score : 0.2802
# ====================================================================================================
#
# ====================================================================================================
# 🔢 Product #3507
# 🆔 Product ID       : eb52d490-8bf2-48ca-a0af-338795ce7e52
# 🛒 Name             : Men’s Robe, Kimono Waffle Spa Bathrobe
# 🖼️  Image URL       : https://m.media-amazon.com/images/I/710PWMLT4KL._AC_UL320_.jpg
# 📄 Description      : Men’s Robe, Kimono Waffle Spa Bathrobe
# 🏷️  Tags            : mens, robe, kimono, waffle, spa, bathrobe
# 🌱 Organic          : ❌ No
# 📦 Base Price       : ₹32.0
# 📊 Sustainable Score: 0.0/100
# 🟩 Green Points     : 0.0
# 🌍 Emissions        : 0.0 kg CO₂
# 💧 Water Saved      : 0.0 L
# 🧪 Energy Used      : 0.0 kWh
# 🚯 Plastic Avoided  : 0.0 g
# 🕒 Created At       : 2025-06-18 02:15:48.255
# 📈 Similarity Score : 0.2760
# ====================================================================================================
#
# ====================================================================================================
# 🔢 Product #101
# 🆔 Product ID       : P000144
# 🛒 Name             : Random House mH-691 Book
# 🖼️  Image URL       : https://res.cloudinary.com/ddr2iwcho/image/upload/v1750104231/products/bsmx3trkwuybxoma9ucf.jpg
# 📄 Description      : Random House's premium quality books product offering top-notch performance and durability. Highly r...
# 🏷️  Tags            : books, study, reading, house, the random house, etiquette
# 🌱 Organic          : ❌ No
# 📦 Base Price       : ₹707.0
# 📊 Sustainable Score: 0.0/100
# 🟩 Green Points     : 0.0
# 🌍 Emissions        : 0.0 kg CO₂
# 💧 Water Saved      : 0.0 L
# 🧪 Energy Used      : 0.0 kWh
# 🚯 Plastic Avoided  : 0.0 g
# 🕒 Created At       : 2025-06-16 20:03:52.521
# 📈 Similarity Score : 0.2695
# ====================================================================================================
#
# ====================================================================================================
# 🔢 Product #80
# 🆔 Product ID       : P000078
# 🛒 Name             : Philips dd-976 Home & Kitchen
# 🖼️  Image URL       : https://res.cloudinary.com/ddr2iwcho/image/upload/v1750104184/products/bx6xos4uxb7jtmjdxqhe.jpg
# 📄 Description      : Philips's premium quality home & kitchen product offering top-notch performance and durability. High...
# 🏷️  Tags            : home & kitchen, kitchen, home, phillips, automatic cooking, food-maker, cooking
# 🌱 Organic          : ❌ No
# 📦 Base Price       : ₹1478.0
# 📊 Sustainable Score: 0.0/100
# 🟩 Green Points     : 0.0
# 🌍 Emissions        : 0.0 kg CO₂
# 💧 Water Saved      : 0.0 L
# 🧪 Energy Used      : 0.0 kWh
# 🚯 Plastic Avoided  : 0.0 g
# 🕒 Created At       : 2025-06-16 20:03:05.921
# 📈 Similarity Score : 0.2692
# ====================================================================================================
#
# ====================================================================================================
# 🔢 Product #139
# 🆔 Product ID       : P000256
# 🛒 Name             : Bosch PY-915 Automotive
# 🖼️  Image URL       : https://res.cloudinary.com/ddr2iwcho/image/upload/v1750104337/products/nmhubj7k8gvva1zzhl98.jpg
# 📄 Description      : Bosch's premium quality automotive product offering top-notch performance and durability. Highly rat...
# 🏷️  Tags            : automotive, home essentials, bosch, inverter battery, battery
# 🌱 Organic          : ❌ No
# 📦 Base Price       : ₹546.0
# 📊 Sustainable Score: 0.0/100
# 🟩 Green Points     : 0.0
# 🌍 Emissions        : 0.0 kg CO₂
# 💧 Water Saved      : 0.0 L
# 🧪 Energy Used      : 0.0 kWh
# 🚯 Plastic Avoided  : 0.0 g
# 🕒 Created At       : 2025-06-16 20:05:39.147
# 📈 Similarity Score : 0.2688
# ====================================================================================================

# %%
import torch
torch.save(product_embeddings, "embeddings.pt")

# %%
from sentence_transformers import SentenceTransformer, util
import pandas as pd

model = SentenceTransformer("all-MiniLM-L6-v2")

# Encode all product texts once
product_embeddings = torch.load("embeddings.pt")

import random

def search_products(query, top_k=50):
    query_embedding = model.encode(query, convert_to_tensor=True)
    cosine_scores = util.cos_sim(query_embedding, product_embeddings)[0]
    df["similarity"] = cosine_scores.cpu().numpy()

    # Step 1: Get top 5 high-scoring eco-friendly products
    eco_sorted = df[(df["isOrganic"] == True) & (df["sustainableScore"] >= 85)].sort_values(by="similarity", ascending=False)
    top_eco = eco_sorted.head(min(5, len(eco_sorted)))

    # Step 2: Prepare the remaining pool
    rest_df = df[~df.index.isin(top_eco.index)]
    rest_eco = rest_df[(rest_df["isOrganic"] == True) & (rest_df["sustainableScore"] >= 75)]
    rest_non_eco = rest_df[~rest_df.index.isin(rest_eco.index)]

    # Step 3: Calculate 3:2 ratio
    remaining_needed = top_k - len(top_eco)
    non_eco_count = int((3/5) * remaining_needed)
    eco_count = remaining_needed - non_eco_count  # remaining 2/5

    # Step 4: Select top results and shuffle
    rest_eco_top = rest_eco.sort_values(by="similarity", ascending=False).head(eco_count)
    rest_non_eco_top = rest_non_eco.sort_values(by="similarity", ascending=False).head(non_eco_count)
    mixed_rest = pd.concat([rest_eco_top, rest_non_eco_top]).sample(frac=1, random_state=42).reset_index(drop=True)

    # Step 5: Final result
    final_df = pd.concat([top_eco, mixed_rest], ignore_index=True)
    return final_df.head(top_k)
    
# Example usage
def display_full_product_details(results_df):
    for idx, row in results_df.iterrows():
        print(f"\n{'='*100}")
        print(f"🔢 Product #{idx + 1}")
        print(f"🆔 Product ID       : {row.get('productId', 'N/A')}")
        print(f"🛒 Name             : {row.get('name', 'N/A')}")
        print(f"🖼️  Image URL       : {row.get('images', '').split(',')[0] if row.get('images') else 'No image'}")
        print(f"📄 Description      : {row.get('description', '')[:100]}{'...' if len(row.get('description', '')) > 100 else ''}")
        print(f"🏷️  Tags            : {row.get('tags', 'None')}")
        print(f"🌱 Organic          : {'✅ Yes' if row.get('isOrganic') else '❌ No'}")
        print(f"📦 Base Price       : ₹{row.get('basePrice', 'N/A')}")
        print(f"📊 Sustainable Score: {row.get('sustainableScore', 0)}/100")
        print(f"🟩 Green Points     : {row.get('greenPoints', 0)}")
        print(f"🌍 Emissions        : {row.get('emissions', 0)} kg CO₂")
        print(f"💧 Water Saved      : {row.get('waterSaved', 0)} L")
        print(f"🧪 Energy Used      : {row.get('energyUsed', 0)} kWh")
        print(f"🚯 Plastic Avoided  : {row.get('plasticAvoided', 0)} g")
        print(f"🕒 Created At       : {row.get('createdAt', 'N/A')}")
        print(f"📈 Similarity Score : {row.get('similarity', 0):.4f}")
        print(f"{'='*100}")

# Run and display
results = search_products("mens tshirt", top_k=50)
display_full_product_details(results)
# Out:
# ====================================================================================================
# 🔢 Product #1
# 🆔 Product ID       : 1829fa85-7037-4525-b067-8ce3aaafd789
# 🛒 Name             : Eco-Friendly Mens T Shirt - Short Sleeve Crew Neck Soft Fitted Tees S - 4XL Fresh Classic Tshirt
# 🖼️  Image URL       : https://m.media-amazon.com/images/I/71NZl070rtL._AC_UL320_.jpg
# 📄 Description      : This product is made with sustainable, organic, and eco-friendly materials. Mens T Shirt - Short Sle...
# 🏷️  Tags            : eco-friendly, sustainable, green, organic
# 🌱 Organic          : ✅ Yes
# 📦 Base Price       : ₹53.0
# 📊 Sustainable Score: 87.0/100
# 🟩 Green Points     : 70.0
# 🌍 Emissions        : 15.0 kg CO₂
# 💧 Water Saved      : 9.0 L
# 🧪 Energy Used      : 28.0 kWh
# 🚯 Plastic Avoided  : 19.0 g
# 🕒 Created At       : 2025-06-17 10:47:08.918
# 📈 Similarity Score : 0.5978
# ====================================================================================================
#
# ====================================================================================================
# 🔢 Product #2
# 🆔 Product ID       : 44930aa5-e6b4-40b4-a7d1-05a93f4ec4aa
# 🛒 Name             : Eco-Friendly INTO The AM Mens T Shirt - Short Sleeve Crew Neck Soft Fitted Tees S - 4XL Fresh Classic Basic Essential Tshirts
# 🖼️  Image URL       : https://m.media-amazon.com/images/I/71r7JAOqOML._AC_UL320_.jpg
# 📄 Description      : This product is made with sustainable, organic, and eco-friendly materials. INTO The AM Mens T Shirt...
# 🏷️  Tags            : eco-friendly, sustainable, green, organic
# 🌱 Organic          : ✅ Yes
# 📦 Base Price       : ₹100.0
# 📊 Sustainable Score: 88.0/100
# 🟩 Green Points     : 51.0
# 🌍 Emissions        : 26.0 kg CO₂
# 💧 Water Saved      : 68.0 L
# 🧪 Energy Used      : 29.0 kWh
# 🚯 Plastic Avoided  : 23.0 g
# 🕒 Created At       : 2025-06-17 10:48:01.757
# 📈 Similarity Score : 0.5830
# ====================================================================================================
#
# ====================================================================================================
# 🔢 Product #3
# 🆔 Product ID       : 1f5df0ec-81a1-487f-a047-54c5eddf2ba8
# 🛒 Name             : Eco-Friendly Mens 90s Vintage Oversize Shirts Summer Unisex Hipster Printed Casual Tee Streetwear Harajuku Top Tshirt
# 🖼️  Image URL       : https://m.media-amazon.com/images/I/61CagmjbIdL._AC_UL320_.jpg
# 📄 Description      : This product is made with sustainable, organic, and eco-friendly materials. Mens 90s Vintage Oversiz...
# 🏷️  Tags            : eco-friendly, sustainable, green, organic
# 🌱 Organic          : ✅ Yes
# 📦 Base Price       : ₹39.0
# 📊 Sustainable Score: 86.0/100
# 🟩 Green Points     : 72.0
# 🌍 Emissions        : 17.0 kg CO₂
# 💧 Water Saved      : 9.0 L
# 🧪 Energy Used      : 12.0 kWh
# 🚯 Plastic Avoided  : 28.0 g
# 🕒 Created At       : 2025-06-17 10:47:55.305
# 📈 Similarity Score : 0.5598
# ====================================================================================================
#
# ====================================================================================================
# 🔢 Product #4
# 🆔 Product ID       : e30bb826-cb03-4c76-9c00-66d3f6695beb
# 🛒 Name             : DOMIN8 organic T-shirt
# 🖼️  Image URL       : https://res.cloudinary.com/ddr2iwcho/image/upload/v1750085618/products/xmummzkcca27qetm3yny.jpg
# 📄 Description      : DOMIN8 Men Organic Cotton Recycled Polyester Melange Effect T-Shirt | Stylish Tshirts for Men | Soft...
# 🏷️  Tags            : Clothing, organic,
# 🌱 Organic          : ✅ Yes
# 📦 Base Price       : ₹672.0
# 📊 Sustainable Score: 90.0/100
# 🟩 Green Points     : 13.0
# 🌍 Emissions        : 59.0 kg CO₂
# 💧 Water Saved      : 69.0 L
# 🧪 Energy Used      : 60.0 kWh
# 🚯 Plastic Avoided  : 6.0 g
# 🕒 Created At       : 2025-06-16 14:53:40.741
# 📈 Similarity Score : 0.5491
# ====================================================================================================
#
# ====================================================================================================
# 🔢 Product #5
# 🆔 Product ID       : fec4afff-dee1-4a96-83fa-df540d3b4594
# 🛒 Name             : Men's Bamboo Nightshirt Short Sleeve Nightgown Comfy Stretchy Sleep Shirt Henley Sleepwear
# 🖼️  Image URL       : https://m.media-amazon.com/images/I/61nI2we5ELL._AC_UL320_.jpg
# 📄 Description      : Men's Bamboo Nightshirt Short Sleeve Nightgown Comfy Stretchy Sleep Shirt Henley Sleepwear
# 🏷️  Tags            : eco-friendly, sustainable, organic, mens, nightshirt, nightgown, comfy, stretchy, sleep, henley, sleepwear, shirt
# 🌱 Organic          : ✅ Yes
# 📦 Base Price       : ₹33.0
# 📊 Sustainable Score: 96.0/100
# 🟩 Green Points     : 72.0
# 🌍 Emissions        : 22.0 kg CO₂
# 💧 Water Saved      : 48.0 L
# 🧪 Energy Used      : 17.0 kWh
# 🚯 Plastic Avoided  : 29.0 g
# 🕒 Created At       : 2025-06-18 02:15:00.911
# 📈 Similarity Score : 0.5365
# ====================================================================================================
#
# ====================================================================================================
# 🔢 Product #6
# 🆔 Product ID       : 7602290d-3453-41b2-80f4-1d0dcbc5726e
# 🛒 Name             : Men's Jersey Short Sleeve Tee
# 🖼️  Image URL       : https://m.media-amazon.com/images/I/61YVC2pcf7L._AC_UL320_.jpg
# 📄 Description      : Imported from Kaggle: Men's Jersey Short Sleeve Tee
# 🏷️  Tags            : mens, jersey
# 🌱 Organic          : ❌ No
# 📦 Base Price       : ₹46.0
# 📊 Sustainable Score: 0.0/100
# 🟩 Green Points     : 0.0
# 🌍 Emissions        : 0.0 kg CO₂
# 💧 Water Saved      : 0.0 L
# 🧪 Energy Used      : 0.0 kWh
# 🚯 Plastic Avoided  : 0.0 g
# 🕒 Created At       : 2025-06-17 10:50:27.781
# 📈 Similarity Score : 0.5509
# ====================================================================================================
#
# ====================================================================================================
# 🔢 Product #7
# 🆔 Product ID       : 0e811d4b-d05f-40e1-b5f5-15b0fec206c3
# 🛒 Name             : Men's T-Shirt
# 🖼️  Image URL       : https://m.media-amazon.com/images/I/91iqILzTIUL._AC_UL320_.jpg
# 📄 Description      : Imported from Kaggle: Men's T-Shirt
# 🏷️  Tags            : mens, tshirt, shirt
# 🌱 Organic          : ❌ No
# 📦 Base Price       : ₹16.0
# 📊 Sustainable Score: 0.0/100
# 🟩 Green Points     : 0.0
# 🌍 Emissions        : 0.0 kg CO₂
# 💧 Water Saved      : 0.0 L
# 🧪 Energy Used      : 0.0 kWh
# 🚯 Plastic Avoided  : 0.0 g
# 🕒 Created At       : 2025-06-17 10:50:44.984
# 📈 Similarity Score : 0.5771
# ====================================================================================================
#
# ====================================================================================================
# 🔢 Product #8
# 🆔 Product ID       : b5576e4a-2243-4b35-967e-2cfc6fff704e
# 🛒 Name             : Men's Loose Fit Heavyweight Long Logo Sleeve Graphic T-Shirt
# 🖼️  Image URL       : https://m.media-amazon.com/images/I/61jt2Uk0zTL._AC_UL320_.jpg
# 📄 Description      : Imported from Kaggle: Men's Loose Fit Heavyweight Long Logo Sleeve Graphic T-Shirt
# 🏷️  Tags            : mens, loose, heavyweight, logo, graphic, tshirt, shirt
# 🌱 Organic          : ❌ No
# 📦 Base Price       : ₹30.0
# 📊 Sustainable Score: 0.0/100
# 🟩 Green Points     : 0.0
# 🌍 Emissions        : 0.0 kg CO₂
# 💧 Water Saved      : 0.0 L
# 🧪 Energy Used      : 0.0 kWh
# 🚯 Plastic Avoided  : 0.0 g
# 🕒 Created At       : 2025-06-17 10:49:32.175
# 📈 Similarity Score : 0.5745
# ====================================================================================================
#
# ====================================================================================================
# 🔢 Product #9
# 🆔 Product ID       : 7e313ebe-0718-4b33-9f4d-bdbb6cb7f8d2
# 🛒 Name             : Men's Metallic T Shirt Holographic Round Neck Short Sleeve Shiny Tee Tops
# 🖼️  Image URL       : https://m.media-amazon.com/images/I/71LkYKiqnYL._AC_UL320_.jpg
# 📄 Description      : Men's Metallic T Shirt Holographic Round Neck Short Sleeve Shiny Tee Tops
# 🏷️  Tags            : mens, metallic, holographic, round, neck, shiny, tops, shirt
# 🌱 Organic          : ❌ No
# 📦 Base Price       : ₹24.0
# 📊 Sustainable Score: 0.0/100
# 🟩 Green Points     : 0.0
# 🌍 Emissions        : 0.0 kg CO₂
# 💧 Water Saved      : 0.0 L
# 🧪 Energy Used      : 0.0 kWh
# 🚯 Plastic Avoided  : 0.0 g
# 🕒 Created At       : 2025-06-18 02:16:13.818
# 📈 Similarity Score : 0.5439
# ====================================================================================================
#
# ====================================================================================================
# 🔢 Product #10
# 🆔 Product ID       : 6cbff2fe-5dd6-4245-b50e-89acac76793b
# 🛒 Name             : Mens Distressed Henley Shirts Retro Short Sleeve Tee Shirts Casual Button Down Washed T-Shirts for Men
# 🖼️  Image URL       : https://m.media-amazon.com/images/I/61bJGbuOrlL._AC_UL320_.jpg
# 📄 Description      : Imported from Kaggle: Mens Distressed Henley Shirts Retro Short Sleeve Tee Shirts Casual Button Down...
# 🏷️  Tags            : mens, distressed, henley, shirts, retro, shirts, button, down, washed, tshirts, shirt
# 🌱 Organic          : ❌ No
# 📦 Base Price       : ₹30.0
# 📊 Sustainable Score: 0.0/100
# 🟩 Green Points     : 0.0
# 🌍 Emissions        : 0.0 kg CO₂
# 💧 Water Saved      : 0.0 L
# 🧪 Energy Used      : 0.0 kWh
# 🚯 Plastic Avoided  : 0.0 g
# 🕒 Created At       : 2025-06-17 10:50:23.632
# 📈 Similarity Score : 0.5559
# ====================================================================================================
#
# ====================================================================================================
# 🔢 Product #11
# 🆔 Product ID       : 50e404ff-f093-4a80-82df-0b3c0af931e1
# 🛒 Name             : Men's Short-Sleeve Flex Twill Work Shirt
# 🖼️  Image URL       : https://m.media-amazon.com/images/I/81WjD4sKeSL._AC_UL320_.jpg
# 📄 Description      : Imported from Kaggle: Men's Short-Sleeve Flex Twill Work Shirt
# 🏷️  Tags            : mens, shortsleeve, flex, twill, work, shirt
# 🌱 Organic          : ❌ No
# 📦 Base Price       : ₹30.0
# 📊 Sustainable Score: 0.0/100
# 🟩 Green Points     : 0.0
# 🌍 Emissions        : 0.0 kg CO₂
# 💧 Water Saved      : 0.0 L
# 🧪 Energy Used      : 0.0 kWh
# 🚯 Plastic Avoided  : 0.0 g
# 🕒 Created At       : 2025-06-17 10:49:09.381
# 📈 Similarity Score : 0.5452
# ====================================================================================================
#
# ====================================================================================================
# 🔢 Product #12
# 🆔 Product ID       : 6d29d1d4-3deb-4dec-8074-031424d641c1
# 🛒 Name             : Eco-Friendly Mens Button Down Shirts Regular Fit Long Sleeve Casual Plaid Flannel Shirt
# 🖼️  Image URL       : https://m.media-amazon.com/images/I/91CwZqgpsnL._AC_UL320_.jpg
# 📄 Description      : This product is made with sustainable, organic, and eco-friendly materials. Mens Button Down Shirts ...
# 🏷️  Tags            : eco-friendly, sustainable, green, organic
# 🌱 Organic          : ✅ Yes
# 📦 Base Price       : ₹20.0
# 📊 Sustainable Score: 78.0/100
# 🟩 Green Points     : 34.0
# 🌍 Emissions        : 18.0 kg CO₂
# 💧 Water Saved      : 19.0 L
# 🧪 Energy Used      : 30.0 kWh
# 🚯 Plastic Avoided  : 16.0 g
# 🕒 Created At       : 2025-06-17 10:46:34.922
# 📈 Similarity Score : 0.5090
# ====================================================================================================
#
# ====================================================================================================
# 🔢 Product #13
# 🆔 Product ID       : f37331a5-9820-436f-9265-5eb675ae6753
# 🛒 Name             : Men's Originals T-Shirt, 100% Cotton Tees for Men, Short-Sleeve T-Shirt, Available in Tall
# 🖼️  Image URL       : https://m.media-amazon.com/images/I/81pR-PtZX7L._AC_UL320_.jpg
# 📄 Description      : Eco-friendly and sustainable: Men's Originals T-Shirt, 100% Cotton Tees for Men, Short-Sleeve T-Shir...
# 🏷️  Tags            : eco-friendly, sustainable, organic, mens, originals, tshirt, 100, tees, shortsleeve, tshirt, available, tall, shirt
# 🌱 Organic          : ✅ Yes
# 📦 Base Price       : ₹8.0
# 📊 Sustainable Score: 99.0/100
# 🟩 Green Points     : 73.0
# 🌍 Emissions        : 23.0 kg CO₂
# 💧 Water Saved      : 19.0 L
# 🧪 Energy Used      : 28.0 kWh
# 🚯 Plastic Avoided  : 22.0 g
# 🕒 Created At       : 2025-06-17 10:48:40.872
# 📈 Similarity Score : 0.4898
# ====================================================================================================
#
# ====================================================================================================
# 🔢 Product #14
# 🆔 Product ID       : ed43014c-96b7-4b24-a25c-418455b1c1d9
# 🛒 Name             : Coach | Coaching Tee Shirt: Royal Blue, Red, Green, Navy, Black Men Women T-Shirt
# 🖼️  Image URL       : https://m.media-amazon.com/images/I/71bcdCjeyiL._AC_UL320_.jpg
# 📄 Description      : Coach | Coaching Tee Shirt: Royal Blue, Red, Green, Navy, Black Men Women T-Shirt
# 🏷️  Tags            : eco-friendly, sustainable, organic, coach, coaching, royal, blue, red, navy, black, tshirt, shirt
# 🌱 Organic          : ✅ Yes
# 📦 Base Price       : ₹22.0
# 📊 Sustainable Score: 82.0/100
# 🟩 Green Points     : 35.0
# 🌍 Emissions        : 10.0 kg CO₂
# 💧 Water Saved      : 87.0 L
# 🧪 Energy Used      : 23.0 kWh
# 🚯 Plastic Avoided  : 14.0 g
# 🕒 Created At       : 2025-06-18 02:14:45.450
# 📈 Similarity Score : 0.4957
# ====================================================================================================
#
# ====================================================================================================
# 🔢 Product #15
# 🆔 Product ID       : 6f01f651-bf89-49e2-b6de-e5e349fbc3d2
# 🛒 Name             : Eco-Friendly Men's Force Relaxed Fit Midweight Short-Sleeve Pocket T-Shirt
# 🖼️  Image URL       : https://m.media-amazon.com/images/I/51RGmLunegL._AC_UL320_.jpg
# 📄 Description      : This product is made with sustainable, organic, and eco-friendly materials. Men's Force Relaxed Fit ...
# 🏷️  Tags            : eco-friendly, sustainable, green, organic
# 🌱 Organic          : ✅ Yes
# 📦 Base Price       : ₹0.0
# 📊 Sustainable Score: 86.0/100
# 🟩 Green Points     : 64.0
# 🌍 Emissions        : 26.0 kg CO₂
# 💧 Water Saved      : 74.0 L
# 🧪 Energy Used      : 21.0 kWh
# 🚯 Plastic Avoided  : 19.0 g
# 🕒 Created At       : 2025-06-17 10:46:09.641
# 📈 Similarity Score : 0.5114
# ====================================================================================================
#
# ====================================================================================================
# 🔢 Product #16
# 🆔 Product ID       : 268d95bc-747b-410a-b38c-397312db5975
# 🛒 Name             : Eco-Friendly Men's 3 Pack Workout Shirts Dry Fit Moisture Wicking Short Sleeve Mesh Athletic T-Shirts
# 🖼️  Image URL       : https://m.media-amazon.com/images/I/714cpNjalzS._AC_UL320_.jpg
# 📄 Description      : This product is made with sustainable, organic, and eco-friendly materials. Men's 3 Pack Workout Shi...
# 🏷️  Tags            : eco-friendly, sustainable, green, organic
# 🌱 Organic          : ✅ Yes
# 📦 Base Price       : ₹36.0
# 📊 Sustainable Score: 89.0/100
# 🟩 Green Points     : 59.0
# 🌍 Emissions        : 15.0 kg CO₂
# 💧 Water Saved      : 8.0 L
# 🧪 Energy Used      : 22.0 kWh
# 🚯 Plastic Avoided  : 12.0 g
# 🕒 Created At       : 2025-06-17 10:46:39.426
# 📈 Similarity Score : 0.5044
# ====================================================================================================
#
# ====================================================================================================
# 🔢 Product #17
# 🆔 Product ID       : 0032abfb-6464-4f79-85a9-d33ff6c52af8
# 🛒 Name             : Mens Mock Turtleneck T-Shirt Long Sleeve Pullover Basic Designed Undershirt Stretch Lightweight Top
# 🖼️  Image URL       : https://m.media-amazon.com/images/I/51xlQpzY9gS._AC_UL320_.jpg
# 📄 Description      : Mens Mock Turtleneck T-Shirt Long Sleeve Pullover Basic Designed Undershirt Stretch Lightweight Top
# 🏷️  Tags            : mens, mock, turtleneck, tshirt, pullover, basic, designed, undershirt, stretch, lightweight, top, shirt
# 🌱 Organic          : ❌ No
# 📦 Base Price       : ₹23.0
# 📊 Sustainable Score: 0.0/100
# 🟩 Green Points     : 0.0
# 🌍 Emissions        : 0.0 kg CO₂
# 💧 Water Saved      : 0.0 L
# 🧪 Energy Used      : 0.0 kWh
# 🚯 Plastic Avoided  : 0.0 g
# 🕒 Created At       : 2025-06-18 02:15:10.432
# 📈 Similarity Score : 0.5806
# ====================================================================================================
#
# ====================================================================================================
# 🔢 Product #18
# 🆔 Product ID       : 40147182-d0e9-4f10-abb2-73570170d1bd
# 🛒 Name             : Men's Training T-Shirt
# 🖼️  Image URL       : https://m.media-amazon.com/images/I/411Pn95TGoL._AC_UL320_.jpg
# 📄 Description      : Imported from Kaggle: Men's Training T-Shirt
# 🏷️  Tags            : mens, training, tshirt, shirt
# 🌱 Organic          : ❌ No
# 📦 Base Price       : ₹28.0
# 📊 Sustainable Score: 0.0/100
# 🟩 Green Points     : 0.0
# 🌍 Emissions        : 0.0 kg CO₂
# 💧 Water Saved      : 0.0 L
# 🧪 Energy Used      : 0.0 kWh
# 🚯 Plastic Avoided  : 0.0 g
# 🕒 Created At       : 2025-06-17 10:49:35.048
# 📈 Similarity Score : 0.5609
# ====================================================================================================
#
# ====================================================================================================
# 🔢 Product #19
# 🆔 Product ID       : b1cd36bf-c8c1-43b2-8c9e-da6be9f760f1
# 🛒 Name             : Mens Mock Turtleneck Sweater Short Sleeve Solid Color T-Shirts Basic Slim Fit Knitted Pullover Tees
# 🖼️  Image URL       : https://m.media-amazon.com/images/I/71ebt9HyscL._AC_UL320_.jpg
# 📄 Description      : Imported from Kaggle: Mens Mock Turtleneck Sweater Short Sleeve Solid Color T-Shirts Basic Slim Fit ...
# 🏷️  Tags            : mens, mock, turtleneck, sweater, solid, tshirts, basic, slim, knitted, pullover, tees, shirt
# 🌱 Organic          : ❌ No
# 📦 Base Price       : ₹18.0
# 📊 Sustainable Score: 0.0/100
# 🟩 Green Points     : 0.0
# 🌍 Emissions        : 0.0 kg CO₂
# 💧 Water Saved      : 0.0 L
# 🧪 Energy Used      : 0.0 kWh
# 🚯 Plastic Avoided  : 0.0 g
# 🕒 Created At       : 2025-06-17 10:50:51.900
# 📈 Similarity Score : 0.6045
# ====================================================================================================
#
# ====================================================================================================
# 🔢 Product #20
# 🆔 Product ID       : 9ff96d55-8e76-4c86-98ea-eefc0bad1779
# 🛒 Name             : Men's T-Shirts - Premium Cotton Crew Neck Tees S - 3XL
# 🖼️  Image URL       : https://m.media-amazon.com/images/I/71Rej8mbbqL._AC_UL320_.jpg
# 📄 Description      : Eco-friendly and sustainable: Men's T-Shirts - Premium Cotton Crew Neck Tees S - 3XL
# 🏷️  Tags            : eco-friendly, sustainable, organic, mens, tshirts, premium, neck, tees, 3xl, shirt
# 🌱 Organic          : ✅ Yes
# 📦 Base Price       : ₹25.0
# 📊 Sustainable Score: 86.0/100
# 🟩 Green Points     : 72.0
# 🌍 Emissions        : 30.0 kg CO₂
# 💧 Water Saved      : 77.0 L
# 🧪 Energy Used      : 14.0 kWh
# 🚯 Plastic Avoided  : 28.0 g
# 🕒 Created At       : 2025-06-17 10:48:48.285
# 📈 Similarity Score : 0.4867
# ====================================================================================================
#
# ====================================================================================================
# 🔢 Product #21
# 🆔 Product ID       : c03cb8d3-b1bc-49ef-8ba1-ab5c82e80283
# 🛒 Name             : Eco-Friendly Men's Long Sleeve Dress Shirt Solid Slim Fit Casual Business Formal Button Up Shirts with Pocket
# 🖼️  Image URL       : https://m.media-amazon.com/images/I/61lP4x3H5QL._AC_UL320_.jpg
# 📄 Description      : This product is made with sustainable, organic, and eco-friendly materials. Men's Long Sleeve Dress ...
# 🏷️  Tags            : eco-friendly, sustainable, green, organic
# 🌱 Organic          : ✅ Yes
# 📦 Base Price       : ₹22.0
# 📊 Sustainable Score: 82.0/100
# 🟩 Green Points     : 74.0
# 🌍 Emissions        : 11.0 kg CO₂
# 💧 Water Saved      : 42.0 L
# 🧪 Energy Used      : 28.0 kWh
# 🚯 Plastic Avoided  : 29.0 g
# 🕒 Created At       : 2025-06-17 10:46:42.192
# 📈 Similarity Score : 0.4884
# ====================================================================================================
#
# ====================================================================================================
# 🔢 Product #22
# 🆔 Product ID       : 87e1f1ff-99c1-4ba9-b585-66e1076bbf96
# 🛒 Name             : Men's HeatGear Fitted Long-Sleeve T-Shirt
# 🖼️  Image URL       : https://m.media-amazon.com/images/I/51Rq9iBAbUL._AC_UL320_.jpg
# 📄 Description      : Imported from Kaggle: Men's HeatGear Fitted Long-Sleeve T-Shirt
# 🏷️  Tags            : mens, heatgear, fitted, longsleeve, tshirt, shirt
# 🌱 Organic          : ❌ No
# 📦 Base Price       : ₹25.0
# 📊 Sustainable Score: 0.0/100
# 🟩 Green Points     : 0.0
# 🌍 Emissions        : 0.0 kg CO₂
# 💧 Water Saved      : 0.0 L
# 🧪 Energy Used      : 0.0 kWh
# 🚯 Plastic Avoided  : 0.0 g
# 🕒 Created At       : 2025-06-17 10:51:20.310
# 📈 Similarity Score : 0.5448
# ====================================================================================================
#
# ====================================================================================================
# 🔢 Product #23
# 🆔 Product ID       : 242e5505-3347-471e-a676-efba79ca92c8
# 🛒 Name             : Eco-Friendly Mens Fashion Athletic Hoodies Sport Sweatshirt Solid Color Fleece Pullover
# 🖼️  Image URL       : https://m.media-amazon.com/images/I/71OuFgbrnxL._AC_UL320_.jpg
# 📄 Description      : This product is made with sustainable, organic, and eco-friendly materials. Mens Fashion Athletic Ho...
# 🏷️  Tags            : eco-friendly, sustainable, green, organic
# 🌱 Organic          : ✅ Yes
# 📦 Base Price       : ₹24.0
# 📊 Sustainable Score: 79.0/100
# 🟩 Green Points     : 71.0
# 🌍 Emissions        : 16.0 kg CO₂
# 💧 Water Saved      : 60.0 L
# 🧪 Energy Used      : 27.0 kWh
# 🚯 Plastic Avoided  : 28.0 g
# 🕒 Created At       : 2025-06-17 10:48:33.705
# 📈 Similarity Score : 0.4876
# ====================================================================================================
#
# ====================================================================================================
# 🔢 Product #24
# 🆔 Product ID       : 28bced67-3855-4452-b568-9ccdb3569b35
# 🛒 Name             : Eco-Friendly Men's Long Sleeve Button Up Shirts Solid Slim Fit Casual Business Formal Dress Shirt
# 🖼️  Image URL       : https://m.media-amazon.com/images/I/61BjRMmm4DS._AC_UL320_.jpg
# 📄 Description      : This product is made with sustainable, organic, and eco-friendly materials. Men's Long Sleeve Button...
# 🏷️  Tags            : eco-friendly, sustainable, green, organic
# 🌱 Organic          : ✅ Yes
# 📦 Base Price       : ₹22.0
# 📊 Sustainable Score: 90.0/100
# 🟩 Green Points     : 44.0
# 🌍 Emissions        : 25.0 kg CO₂
# 💧 Water Saved      : 71.0 L
# 🧪 Energy Used      : 19.0 kWh
# 🚯 Plastic Avoided  : 14.0 g
# 🕒 Created At       : 2025-06-17 10:45:48.806
# 📈 Similarity Score : 0.4937
# ====================================================================================================
#
# ====================================================================================================
# 🔢 Product #25
# 🆔 Product ID       : f05a9ca2-1251-4ddf-8d8e-c0e4a401f7c7
# 🛒 Name             : Eco-Friendly Men's Short Sleeve Knit Shirts Vintage Button Down Polo Shirt Casual Beach Tops
# 🖼️  Image URL       : https://m.media-amazon.com/images/I/81QYJ7+gfJL._AC_UL320_.jpg
# 📄 Description      : This product is made with sustainable, organic, and eco-friendly materials. Men's Short Sleeve Knit ...
# 🏷️  Tags            : eco-friendly, sustainable, green, organic
# 🌱 Organic          : ✅ Yes
# 📦 Base Price       : ₹34.0
# 📊 Sustainable Score: 85.0/100
# 🟩 Green Points     : 36.0
# 🌍 Emissions        : 12.0 kg CO₂
# 💧 Water Saved      : 7.0 L
# 🧪 Energy Used      : 18.0 kWh
# 🚯 Plastic Avoided  : 20.0 g
# 🕒 Created At       : 2025-06-17 10:47:22.108
# 📈 Similarity Score : 0.4874
# ====================================================================================================
#
# ====================================================================================================
# 🔢 Product #26
# 🆔 Product ID       : 3f4cf4ce-0b59-42dd-86c1-b5a7e5ff26d5
# 🛒 Name             : Men's T-Shirt, Classic Tee for Men, Men's T-Shirt, Men's Tee (Reg. or Big & Tall)
# 🖼️  Image URL       : https://m.media-amazon.com/images/I/81sXWS93m-L._AC_UL320_.jpg
# 📄 Description      : Imported from Kaggle: Men's T-Shirt, Classic Tee for Men, Men's T-Shirt, Men's Tee (Reg. or Big & Ta...
# 🏷️  Tags            : mens, tshirt, mens, tshirt, mens, reg, big, tall, shirt
# 🌱 Organic          : ❌ No
# 📦 Base Price       : ₹12.0
# 📊 Sustainable Score: 0.0/100
# 🟩 Green Points     : 0.0
# 🌍 Emissions        : 0.0 kg CO₂
# 💧 Water Saved      : 0.0 L
# 🧪 Energy Used      : 0.0 kWh
# 🚯 Plastic Avoided  : 0.0 g
# 🕒 Created At       : 2025-06-17 10:50:08.221
# 📈 Similarity Score : 0.5541
# ====================================================================================================
#
# ====================================================================================================
# 🔢 Product #27
# 🆔 Product ID       : f729adef-9040-4137-adb8-2b6c6b74f4ef
# 🛒 Name             : Mens Long Sleeve Shirt - #TBT Mens 1990's Clothing - Rugrats, Hey Arnold, Ren and Stimpy
# 🖼️  Image URL       : https://m.media-amazon.com/images/I/61amEXkYvkS._AC_UL320_.jpg
# 📄 Description      : Mens Long Sleeve Shirt - #TBT Mens 1990's Clothing - Rugrats, Hey Arnold, Ren and Stimpy
# 🏷️  Tags            : mens, tbt, mens, 1990s, clothing, rugrats, hey, arnold, ren, stimpy, shirt
# 🌱 Organic          : ❌ No
# 📦 Base Price       : ₹30.0
# 📊 Sustainable Score: 0.0/100
# 🟩 Green Points     : 0.0
# 🌍 Emissions        : 0.0 kg CO₂
# 💧 Water Saved      : 0.0 L
# 🧪 Energy Used      : 0.0 kWh
# 🚯 Plastic Avoided  : 0.0 g
# 🕒 Created At       : 2025-06-18 02:15:09.204
# 📈 Similarity Score : 0.5613
# ====================================================================================================
#
# ====================================================================================================
# 🔢 Product #28
# 🆔 Product ID       : 7c3aff3a-d837-482a-907f-751c29722110
# 🛒 Name             : Men's Team Logo Twill Classic Fit Shirt
# 🖼️  Image URL       : https://m.media-amazon.com/images/I/51KnXqee5uL._AC_UL320_.jpg
# 📄 Description      : Imported from Kaggle: Men's Team Logo Twill Classic Fit Shirt
# 🏷️  Tags            : mens, team, logo, twill, shirt
# 🌱 Organic          : ❌ No
# 📦 Base Price       : ₹70.0
# 📊 Sustainable Score: 0.0/100
# 🟩 Green Points     : 0.0
# 🌍 Emissions        : 0.0 kg CO₂
# 💧 Water Saved      : 0.0 L
# 🧪 Energy Used      : 0.0 kWh
# 🚯 Plastic Avoided  : 0.0 g
# 🕒 Created At       : 2025-06-17 10:50:52.613
# 📈 Similarity Score : 0.5725
# ====================================================================================================
#
# ====================================================================================================
# 🔢 Product #29
# 🆔 Product ID       : 0e569deb-db2e-422c-905c-99c9e2ed11f0
# 🛒 Name             : Eco-Friendly 5 Pack Compression Shirts Men Long Sleeve Rash Guard Athletic Baselayer Undershirt Gear Tshirt for Sports Workout
# 🖼️  Image URL       : https://m.media-amazon.com/images/I/61dIzCKfTuL._AC_UL320_.jpg
# 📄 Description      : This product is made with sustainable, organic, and eco-friendly materials. 5 Pack Compression Shirt...
# 🏷️  Tags            : eco-friendly, sustainable, green, organic
# 🌱 Organic          : ✅ Yes
# 📦 Base Price       : ₹29.0
# 📊 Sustainable Score: 78.0/100
# 🟩 Green Points     : 76.0
# 🌍 Emissions        : 21.0 kg CO₂
# 💧 Water Saved      : 63.0 L
# 🧪 Energy Used      : 25.0 kWh
# 🚯 Plastic Avoided  : 20.0 g
# 🕒 Created At       : 2025-06-17 10:46:31.134
# 📈 Similarity Score : 0.5322
# ====================================================================================================
#
# ====================================================================================================
# 🔢 Product #30
# 🆔 Product ID       : 406b3ee3-83a6-4b3b-b27a-2906cf104857
# 🛒 Name             : Men Turtleneck T-Shirts Long Sleeve Shirt Thermal Tops Lightweight Baselayer Ribbed Pullover Sweaters S-XXL
# 🖼️  Image URL       : https://m.media-amazon.com/images/I/71iUWo826zL._AC_UL320_.jpg
# 📄 Description      : Imported from Kaggle: Men Turtleneck T-Shirts Long Sleeve Shirt Thermal Tops Lightweight Baselayer R...
# 🏷️  Tags            : turtleneck, tshirts, tops, lightweight, baselayer, ribbed, pullover, sweaters, sxxl, shirt
# 🌱 Organic          : ❌ No
# 📦 Base Price       : ₹23.0
# 📊 Sustainable Score: 0.0/100
# 🟩 Green Points     : 0.0
# 🌍 Emissions        : 0.0 kg CO₂
# 💧 Water Saved      : 0.0 L
# 🧪 Energy Used      : 0.0 kWh
# 🚯 Plastic Avoided  : 0.0 g
# 🕒 Created At       : 2025-06-17 10:51:23.689
# 📈 Similarity Score : 0.5623
# ====================================================================================================
#
# ====================================================================================================
# 🔢 Product #31
# 🆔 Product ID       : 166555ba-354d-4b8b-9c56-bce04c20bdc2
# 🛒 Name             : Men's Turtleneck T-Shirts Slim Fit Short Sleeve Sweater Lightweight Mockneck Pullover
# 🖼️  Image URL       : https://m.media-amazon.com/images/I/81E9tRTEjCL._AC_UL320_.jpg
# 📄 Description      : Men's Turtleneck T-Shirts Slim Fit Short Sleeve Sweater Lightweight Mockneck Pullover
# 🏷️  Tags            : mens, turtleneck, tshirts, slim, sweater, lightweight, mockneck, pullover, shirt
# 🌱 Organic          : ❌ No
# 📦 Base Price       : ₹23.0
# 📊 Sustainable Score: 0.0/100
# 🟩 Green Points     : 0.0
# 🌍 Emissions        : 0.0 kg CO₂
# 💧 Water Saved      : 0.0 L
# 🧪 Energy Used      : 0.0 kWh
# 🚯 Plastic Avoided  : 0.0 g
# 🕒 Created At       : 2025-06-18 02:15:48.422
# 📈 Similarity Score : 0.5631
# ====================================================================================================
#
# ====================================================================================================
# 🔢 Product #32
# 🆔 Product ID       : 0d7bfa29-027c-4eec-b65c-80740773a4a4
# 🛒 Name             : Eco-Friendly Men Slim Fit Lightweight Long Sleeve Pullover Top Turtleneck T-Shirt
# 🖼️  Image URL       : https://m.media-amazon.com/images/I/51SfpEXtLKL._AC_UL320_.jpg
# 📄 Description      : This product is made with sustainable, organic, and eco-friendly materials. Men Slim Fit Lightweight...
# 🏷️  Tags            : eco-friendly, sustainable, green, organic
# 🌱 Organic          : ✅ Yes
# 📦 Base Price       : ₹19.0
# 📊 Sustainable Score: 99.0/100
# 🟩 Green Points     : 50.0
# 🌍 Emissions        : 13.0 kg CO₂
# 💧 Water Saved      : 39.0 L
# 🧪 Energy Used      : 24.0 kWh
# 🚯 Plastic Avoided  : 25.0 g
# 🕒 Created At       : 2025-06-17 10:47:02.607
# 📈 Similarity Score : 0.5056
# ====================================================================================================
#
# ====================================================================================================
# 🔢 Product #33
# 🆔 Product ID       : 2e092c18-773d-4e05-bf7b-a95f5db69239
# 🛒 Name             : Eco-Friendly Men's Tech 2.0 Short-Sleeve T-Shirt
# 🖼️  Image URL       : https://m.media-amazon.com/images/I/61Eq6uGx22L._AC_UL320_.jpg
# 📄 Description      : This product is made with sustainable, organic, and eco-friendly materials. Men's Tech 2.0 Short-Sle...
# 🏷️  Tags            : eco-friendly, sustainable, green, organic
# 🌱 Organic          : ✅ Yes
# 📦 Base Price       : ₹18.0
# 📊 Sustainable Score: 90.0/100
# 🟩 Green Points     : 33.0
# 🌍 Emissions        : 24.0 kg CO₂
# 💧 Water Saved      : 80.0 L
# 🧪 Energy Used      : 20.0 kWh
# 🚯 Plastic Avoided  : 16.0 g
# 🕒 Created At       : 2025-06-17 10:45:49.565
# 📈 Similarity Score : 0.4902
# ====================================================================================================
#
# ====================================================================================================
# 🔢 Product #34
# 🆔 Product ID       : 6ca8bb94-ccca-4347-98ed-1c7dae476ce9
# 🛒 Name             : 5 Pieces Polyester Adult Tshirts for Sublimation White Blank Crew Neck Men Short Sleeve T-Shirt
# 🖼️  Image URL       : https://m.media-amazon.com/images/I/51JeNRYz0iL._AC_UL320_.jpg
# 📄 Description      : Imported from Kaggle: 5 Pieces Polyester Adult Tshirts for Sublimation White Blank Crew Neck Men Sho...
# 🏷️  Tags            : pieces, polyester, adult, tshirts, sublimation, white, blank, neck, tshirt, shirt
# 🌱 Organic          : ❌ No
# 📦 Base Price       : ₹25.0
# 📊 Sustainable Score: 0.0/100
# 🟩 Green Points     : 0.0
# 🌍 Emissions        : 0.0 kg CO₂
# 💧 Water Saved      : 0.0 L
# 🧪 Energy Used      : 0.0 kWh
# 🚯 Plastic Avoided  : 0.0 g
# 🕒 Created At       : 2025-06-17 10:49:55.217
# 📈 Similarity Score : 0.5569
# ====================================================================================================
#
# ====================================================================================================
# 🔢 Product #35
# 🆔 Product ID       : b183ee43-f57a-4bad-a56a-97e3e6db4e29
# 🛒 Name             : Men's Heavyweight Cotton T Shirt – Basic 6.2 Ounce Short Sleeve V Neck Plain Tee Top Tshirts Regular Big and Tall Size
# 🖼️  Image URL       : https://m.media-amazon.com/images/I/513QILPt26L._AC_UL320_.jpg
# 📄 Description      : Men's Heavyweight Cotton T Shirt – Basic 6.2 Ounce Short Sleeve V Neck Plain Tee Top Tshirts Regular...
# 🏷️  Tags            : eco-friendly, sustainable, organic, mens, heavyweight, basic, ounce, neck, plain, top, tshirts, regular, big, tall, shirt
# 🌱 Organic          : ✅ Yes
# 📦 Base Price       : ₹22.0
# 📊 Sustainable Score: 87.0/100
# 🟩 Green Points     : 76.0
# 🌍 Emissions        : 22.0 kg CO₂
# 💧 Water Saved      : 92.0 L
# 🧪 Energy Used      : 24.0 kWh
# 🚯 Plastic Avoided  : 20.0 g
# 🕒 Created At       : 2025-06-18 02:14:56.508
# 📈 Similarity Score : 0.5285
# ====================================================================================================
#
# ====================================================================================================
# 🔢 Product #36
# 🆔 Product ID       : 0cb0c94d-96a6-4ca7-927d-b36804cdbdd7
# 🛒 Name             : Men's Solid Twill Classic Fit Shirt
# 🖼️  Image URL       : https://m.media-amazon.com/images/I/61Vih3dqfML._AC_UL320_.jpg
# 📄 Description      : Imported from Kaggle: Men's Solid Twill Classic Fit Shirt
# 🏷️  Tags            : mens, solid, twill, shirt
# 🌱 Organic          : ❌ No
# 📦 Base Price       : ₹63.0
# 📊 Sustainable Score: 0.0/100
# 🟩 Green Points     : 0.0
# 🌍 Emissions        : 0.0 kg CO₂
# 💧 Water Saved      : 0.0 L
# 🧪 Energy Used      : 0.0 kWh
# 🚯 Plastic Avoided  : 0.0 g
# 🕒 Created At       : 2025-06-17 10:49:42.620
# 📈 Similarity Score : 0.5474
# ====================================================================================================
#
# ====================================================================================================
# 🔢 Product #37
# 🆔 Product ID       : ae72ab57-db5d-4f59-80de-17ee6a451e08
# 🛒 Name             : Mens Reg Fit Ss Tshirt Zebra Broad Strip
# 🖼️  Image URL       : https://m.media-amazon.com/images/I/71qk1eDZlPL._AC_UL320_.jpg
# 📄 Description      : Mens Reg Fit Ss Tshirt Zebra Broad Strip
# 🏷️  Tags            : mens, reg, tshirt, zebra, broad, strip, shirt
# 🌱 Organic          : ❌ No
# 📦 Base Price       : ₹50.0
# 📊 Sustainable Score: 0.0/100
# 🟩 Green Points     : 0.0
# 🌍 Emissions        : 0.0 kg CO₂
# 💧 Water Saved      : 0.0 L
# 🧪 Energy Used      : 0.0 kWh
# 🚯 Plastic Avoided  : 0.0 g
# 🕒 Created At       : 2025-06-18 02:17:29.900
# 📈 Similarity Score : 0.5890
# ====================================================================================================
#
# ====================================================================================================
# 🔢 Product #38
# 🆔 Product ID       : efd1a1b6-b2e1-4408-97e1-23a1d3862da2
# 🛒 Name             : Men's T-Shirts Moisture-Wicking Crew Neck T-Shirt for Men Multipack Soft Bamboo Viscose Undershirt for Men
# 🖼️  Image URL       : https://m.media-amazon.com/images/I/41pKPVViJjL._AC_UL320_.jpg
# 📄 Description      : Eco-friendly and sustainable: Men's T-Shirts Moisture-Wicking Crew Neck T-Shirt for Men Multipack So...
# 🏷️  Tags            : organic, sustainable, eco-friendly
# 🌱 Organic          : ✅ Yes
# 📦 Base Price       : ₹38.0
# 📊 Sustainable Score: 92.0/100
# 🟩 Green Points     : 48.0
# 🌍 Emissions        : 30.0 kg CO₂
# 💧 Water Saved      : 97.0 L
# 🧪 Energy Used      : 23.0 kWh
# 🚯 Plastic Avoided  : 30.0 g
# 🕒 Created At       : 2025-06-17 10:48:26.796
# 📈 Similarity Score : 0.5219
# ====================================================================================================
#
# ====================================================================================================
# 🔢 Product #39
# 🆔 Product ID       : f27cde5b-3f55-47bd-83b7-0f8e06d3202b
# 🛒 Name             : Mens Distressed Henley Shirts Retro Long Sleeve Tee Shirts Casual Button Down Washed T-Shirts for Men
# 🖼️  Image URL       : https://m.media-amazon.com/images/I/61SPc1MDACL._AC_UL320_.jpg
# 📄 Description      : Imported from Kaggle: Mens Distressed Henley Shirts Retro Long Sleeve Tee Shirts Casual Button Down ...
# 🏷️  Tags            : mens, distressed, henley, shirts, retro, shirts, button, down, washed, tshirts, shirt
# 🌱 Organic          : ❌ No
# 📦 Base Price       : ₹30.0
# 📊 Sustainable Score: 0.0/100
# 🟩 Green Points     : 0.0
# 🌍 Emissions        : 0.0 kg CO₂
# 💧 Water Saved      : 0.0 L
# 🧪 Energy Used      : 0.0 kWh
# 🚯 Plastic Avoided  : 0.0 g
# 🕒 Created At       : 2025-06-17 10:51:18.773
# 📈 Similarity Score : 0.5568
# ====================================================================================================
#
# ====================================================================================================
# 🔢 Product #40
# 🆔 Product ID       : 6983c02d-3fb4-49e0-a1c6-ce6ca9450f15
# 🛒 Name             : Men’s Short Sleeve Graphic T-shirt Collection
# 🖼️  Image URL       : https://m.media-amazon.com/images/I/81vCTr9UaEL._AC_UL320_.jpg
# 📄 Description      : Imported from Kaggle: Men’s Short Sleeve Graphic T-shirt Collection
# 🏷️  Tags            : mens, graphic, tshirt, collection, shirt
# 🌱 Organic          : ❌ No
# 📦 Base Price       : ₹12.0
# 📊 Sustainable Score: 0.0/100
# 🟩 Green Points     : 0.0
# 🌍 Emissions        : 0.0 kg CO₂
# 💧 Water Saved      : 0.0 L
# 🧪 Energy Used      : 0.0 kWh
# 🚯 Plastic Avoided  : 0.0 g
# 🕒 Created At       : 2025-06-17 10:50:25.776
# 📈 Similarity Score : 0.5843
# ====================================================================================================
#
# ====================================================================================================
# 🔢 Product #41
# 🆔 Product ID       : 6e55874c-e40e-4bea-b3c3-53805b522bcf
# 🛒 Name             : Men's See Through Long Sleeve Mock Neck Sheer Mesh Tee Shirt
# 🖼️  Image URL       : https://m.media-amazon.com/images/I/71FQkrCYf-L._AC_UL320_.jpg
# 📄 Description      : Men's See Through Long Sleeve Mock Neck Sheer Mesh Tee Shirt
# 🏷️  Tags            : mens, see, through, mock, neck, sheer, mesh, shirt
# 🌱 Organic          : ❌ No
# 📦 Base Price       : ₹27.0
# 📊 Sustainable Score: 0.0/100
# 🟩 Green Points     : 0.0
# 🌍 Emissions        : 0.0 kg CO₂
# 💧 Water Saved      : 0.0 L
# 🧪 Energy Used      : 0.0 kWh
# 🚯 Plastic Avoided  : 0.0 g
# 🕒 Created At       : 2025-06-18 02:16:04.191
# 📈 Similarity Score : 0.5556
# ====================================================================================================
#
# ====================================================================================================
# 🔢 Product #42
# 🆔 Product ID       : 08348999-f767-47dd-b4d2-496e4c4ae90b
# 🛒 Name             : Eco-Friendly Men's Tech Stretch Tank T-Shirt
# 🖼️  Image URL       : https://m.media-amazon.com/images/I/71Hx5x6EINS._AC_UL320_.jpg
# 📄 Description      : This product is made with sustainable, organic, and eco-friendly materials. Men's Tech Stretch Tank ...
# 🏷️  Tags            : eco-friendly, sustainable, green, organic
# 🌱 Organic          : ✅ Yes
# 📦 Base Price       : ₹12.0
# 📊 Sustainable Score: 78.0/100
# 🟩 Green Points     : 31.0
# 🌍 Emissions        : 11.0 kg CO₂
# 💧 Water Saved      : 67.0 L
# 🧪 Energy Used      : 10.0 kWh
# 🚯 Plastic Avoided  : 27.0 g
# 🕒 Created At       : 2025-06-17 10:48:11.484
# 📈 Similarity Score : 0.4916
# ====================================================================================================
#
# ====================================================================================================
# 🔢 Product #43
# 🆔 Product ID       : c43f607e-8eeb-42b0-8ea9-de3ef9e5a82f
# 🛒 Name             : Men's Classic Jersey Long Sleeve Script T-Shirt
# 🖼️  Image URL       : https://m.media-amazon.com/images/I/71s7MAw++9L._AC_UL320_.jpg
# 📄 Description      : Men's Classic Jersey Long Sleeve Script T-Shirt
# 🏷️  Tags            : mens, jersey, script, tshirt, shirt
# 🌱 Organic          : ❌ No
# 📦 Base Price       : ₹18.0
# 📊 Sustainable Score: 0.0/100
# 🟩 Green Points     : 0.0
# 🌍 Emissions        : 0.0 kg CO₂
# 💧 Water Saved      : 0.0 L
# 🧪 Energy Used      : 0.0 kWh
# 🚯 Plastic Avoided  : 0.0 g
# 🕒 Created At       : 2025-06-18 02:17:46.161
# 📈 Similarity Score : 0.5877
# ====================================================================================================
#
# ====================================================================================================
# 🔢 Product #44
# 🆔 Product ID       : fc86a4ed-c097-4aba-aff3-dfb25e81baf9
# 🛒 Name             : Eco-Friendly Mens T Shirt - Short Sleeve Crew Neck Soft Fitted Tees S - 4XL Fresh Classic Tshirts
# 🖼️  Image URL       : https://m.media-amazon.com/images/I/61E4URgY4xL._AC_UL320_.jpg
# 📄 Description      : This product is made with sustainable, organic, and eco-friendly materials. Mens T Shirt - Short Sle...
# 🏷️  Tags            : eco-friendly, sustainable, green, organic
# 🌱 Organic          : ✅ Yes
# 📦 Base Price       : ₹23.0
# 📊 Sustainable Score: 70.0/100
# 🟩 Green Points     : 78.0
# 🌍 Emissions        : 13.0 kg CO₂
# 💧 Water Saved      : 43.0 L
# 🧪 Energy Used      : 26.0 kWh
# 🚯 Plastic Avoided  : 13.0 g
# 🕒 Created At       : 2025-06-17 10:45:44.950
# 📈 Similarity Score : 0.6051
# ====================================================================================================
#
# ====================================================================================================
# 🔢 Product #45
# 🆔 Product ID       : 341f875e-3355-4725-a73a-b7416c886111
# 🛒 Name             : Men's Short Sleeve Classic Woven Shirt
# 🖼️  Image URL       : https://m.media-amazon.com/images/I/711vWq7iMQL._AC_UL320_.jpg
# 📄 Description      : Imported from Kaggle: Men's Short Sleeve Classic Woven Shirt
# 🏷️  Tags            : mens, woven, shirt
# 🌱 Organic          : ❌ No
# 📦 Base Price       : ₹25.0
# 📊 Sustainable Score: 0.0/100
# 🟩 Green Points     : 0.0
# 🌍 Emissions        : 0.0 kg CO₂
# 💧 Water Saved      : 0.0 L
# 🧪 Energy Used      : 0.0 kWh
# 🚯 Plastic Avoided  : 0.0 g
# 🕒 Created At       : 2025-06-17 10:49:21.935
# 📈 Similarity Score : 0.5413
# ====================================================================================================
#
# ====================================================================================================
# 🔢 Product #46
# 🆔 Product ID       : b9d184de-f33e-44b7-a53e-1474f933aaef
# 🛒 Name             : Mens Fashion Short Sleeve Mock Turtleneck Basic Tops Casual Pullover T-Shirt Slim Fit Solid Undershirt
# 🖼️  Image URL       : https://m.media-amazon.com/images/I/51mJcoss1cL._AC_UL320_.jpg
# 📄 Description      : Mens Fashion Short Sleeve Mock Turtleneck Basic Tops Casual Pullover T-Shirt Slim Fit Solid Undershi...
# 🏷️  Tags            : mens, fashion, mock, turtleneck, basic, tops, pullover, tshirt, slim, solid, undershirt, shirt
# 🌱 Organic          : ❌ No
# 📦 Base Price       : ₹19.0
# 📊 Sustainable Score: 0.0/100
# 🟩 Green Points     : 0.0
# 🌍 Emissions        : 0.0 kg CO₂
# 💧 Water Saved      : 0.0 L
# 🧪 Energy Used      : 0.0 kWh
# 🚯 Plastic Avoided  : 0.0 g
# 🕒 Created At       : 2025-06-18 02:16:37.064
# 📈 Similarity Score : 0.5894
# ====================================================================================================
#
# ====================================================================================================
# 🔢 Product #47
# 🆔 Product ID       : 0118a2e2-0a44-4b97-8890-2372396e0b55
# 🛒 Name             : Men's Repeat Logo Cotton T-Shirt
# 🖼️  Image URL       : https://m.media-amazon.com/images/I/61AAPlU9hVL._MCnd_AC_UL320_.jpg
# 📄 Description      : Men's Repeat Logo Cotton T-Shirt
# 🏷️  Tags            : eco-friendly, sustainable, organic, mens, repeat, logo, tshirt, shirt
# 🌱 Organic          : ✅ Yes
# 📦 Base Price       : ₹38.0
# 📊 Sustainable Score: 78.0/100
# 🟩 Green Points     : 45.0
# 🌍 Emissions        : 17.0 kg CO₂
# 💧 Water Saved      : 33.0 L
# 🧪 Energy Used      : 13.0 kWh
# 🚯 Plastic Avoided  : 20.0 g
# 🕒 Created At       : 2025-06-18 02:15:05.415
# 📈 Similarity Score : 0.4969
# ====================================================================================================
#
# ====================================================================================================
# 🔢 Product #48
# 🆔 Product ID       : 201befdc-e3e1-4ad6-b3d3-19a99f4c2048
# 🛒 Name             : Eco-Friendly Henley Long Sleeve Shirts for Men - Mens Henley with Flex Material
# 🖼️  Image URL       : https://m.media-amazon.com/images/I/91SRrJHOR8L._AC_UL320_.jpg
# 📄 Description      : This product is made with sustainable, organic, and eco-friendly materials. Henley Long Sleeve Shirt...
# 🏷️  Tags            : eco-friendly, sustainable, green, organic
# 🌱 Organic          : ✅ Yes
# 📦 Base Price       : ₹45.0
# 📊 Sustainable Score: 88.0/100
# 🟩 Green Points     : 50.0
# 🌍 Emissions        : 28.0 kg CO₂
# 💧 Water Saved      : 16.0 L
# 🧪 Energy Used      : 10.0 kWh
# 🚯 Plastic Avoided  : 11.0 g
# 🕒 Created At       : 2025-06-17 10:47:38.306
# 📈 Similarity Score : 0.4882
# ====================================================================================================
#
# ====================================================================================================
# 🔢 Product #49
# 🆔 Product ID       : 7bf4cac3-0036-4820-832d-f6799d86be91
# 🛒 Name             : Men's Tech 2.0 V-Neck Short-Sleeve T-Shirt
# 🖼️  Image URL       : https://m.media-amazon.com/images/I/51YHDHdR3jL._AC_UL320_.jpg
# 📄 Description      : Imported from Kaggle: Men's Tech 2.0 V-Neck Short-Sleeve T-Shirt
# 🏷️  Tags            : mens, tech, vneck, shortsleeve, tshirt, shirt
# 🌱 Organic          : ❌ No
# 📦 Base Price       : ₹16.0
# 📊 Sustainable Score: 0.0/100
# 🟩 Green Points     : 0.0
# 🌍 Emissions        : 0.0 kg CO₂
# 💧 Water Saved      : 0.0 L
# 🧪 Energy Used      : 0.0 kWh
# 🚯 Plastic Avoided  : 0.0 g
# 🕒 Created At       : 2025-06-17 10:49:05.652
# 📈 Similarity Score : 0.5671
# ====================================================================================================
#
# ====================================================================================================
# 🔢 Product #50
# 🆔 Product ID       : 11ae29a2-8d00-4ad0-9490-5f3f1c1b804d
# 🛒 Name             : Men’s Perfect-T Long Sleeve T-shirt (2-pack)
# 🖼️  Image URL       : https://m.media-amazon.com/images/I/51U+fmaa7aL._AC_UL320_.jpg
# 📄 Description      : Imported from Kaggle: Men’s Perfect-T Long Sleeve T-shirt (2-pack)
# 🏷️  Tags            : mens, perfectt, tshirt, 2pack, shirt
# 🌱 Organic          : ❌ No
# 📦 Base Price       : ₹16.0
# 📊 Sustainable Score: 0.0/100
# 🟩 Green Points     : 0.0
# 🌍 Emissions        : 0.0 kg CO₂
# 💧 Water Saved      : 0.0 L
# 🧪 Energy Used      : 0.0 kWh
# 🚯 Plastic Avoided  : 0.0 g
# 🕒 Created At       : 2025-06-17 10:50:09.450
# 📈 Similarity Score : 0.5515
# ====================================================================================================
